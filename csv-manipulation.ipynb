# %% [markdown]
# This file opens the main csv file (all.csv) and write to a new csv file according to the given fields
#
# filename - the name of the fiile
#
# AGE - Modern or Renaissance
#
# Type - Nature, Love, or Mythology & Folklore
#
# The code reads a poem by poem ('content') and writes to a new csv file
#
#
# e.g.
# modern_love
# This is a poem,
# Roses are red, violets are blue,
# programming in python all the way to the moon.
# ...
# ...
# ...

# %%
from textblob import TextBlob
import csv
data = open('all.csv', encoding="utf-8")
csv_data = csv.reader(data)
data_lines = list(csv_data)
fields = ['modern_love']
filename = 'test2.csv'
AGE = 'Modern'
TYPE = 'Love'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-42d9aba30d47> in <module>
#       1 from textblob import TextBlob
#       2 import csv
# ----> 3 data = open('all.csv', encoding="utf-8")
#       4 csv_data = csv.reader(data)
#       5 data_lines = list(csv_data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all.csv'

# %%
with open('CSVs/'+filename, 'w') as csvfile:
    #creates a csv writer object
    csv_writer = csv.writer(csvfile)
    
    #writing the fields
    csv_writer.writerow(fields)
    
    #writing rows
    for line in data_lines:
        if(line[3] == AGE and line[4] == TYPE):
            #csvfile.write(line[1])
            print(line[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c76b7bb7205a> in <module>
# ----> 1 with open('CSVs/'+filename, 'w') as csvfile:
#       2     #creates a csv writer object
#       3     csv_writer = csv.writer(csvfile)
#       4
#       5     #writing the fields
#
# NameError: name 'filename' is not defined
