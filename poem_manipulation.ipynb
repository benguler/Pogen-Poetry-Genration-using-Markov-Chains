# %% [markdown]
# ### opens a csv file containing one field such as the 'content' of a poem
# ### read the csv file line by line
# ### and write each line plus a lable to a new csv file
# ### e.g. Love is abudant like oxygen,modern_love

# %%
import csv

filename = 'r_nature_proc.csv'
TAG = 'renaissance_nature'
new_filename = 'renaissance_nature7_proc.csv'

with open('CSVs/'+filename, 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter='\n')
    
    #next(csv_reader)
    
    with open ('CSVs/processed/'+new_filename, 'w') as new_file:
        fieldnames = ['poem_line', TAG]
        csv_writer = csv.writer(new_file)
        
        csv_writer.writerow(fieldnames)
        
        for line in csv_reader:
            # write the the contents of the line['content'], and add a tag separated by a comma for each line 
            #print([line[TAG]] + [TAG])            
            csv_writer.writerow([line[TAG]] + [TAG])

            
        print("wrote to csv file: " + new_filename)
# Out:
# wrote to csv file: renaissance_nature7_proc.csv

# %% [markdown]
# ### Opens a processed csv file and uses Naive Bayes Classifier to train a model

# %%
from textblob.classifiers import NaiveBayesClassifier
import csv


with open('CSVs/processed/renaissance_nature_proc.csv', 'r') as csv_file2:
    csv_reader = csv.reader(csv_file2, delimiter =',')
    cl = NaiveBayesClassifier(csv_file2, format="csv")
#     for line in csv_reader:
#         cl.classify()
    #print('With file: ' + new_filename)
    print(cl)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-2add34ed4abe> in <module>
#       5 with open('CSVs/processed/renaissance_nature_proc.csv', 'r') as csv_file2:
#       6     csv_reader = csv.reader(csv_file2, delimiter =',')
# ----> 7     cl = NaiveBayesClassifier(csv_file2, format="csv")
#       8 #     for line in csv_reader:
#       9 #         cl.classify()
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/classifiers.py in __init__(self, train_set, feature_extractor, format, **kwargs)
#     203     def __init__(self, train_set,
#     204                  feature_extractor=basic_extractor, format=None, **kwargs):
# --> 205         super(NLTKClassifier, self).__init__(train_set, feature_extractor, format, **kwargs)
#     206         self.train_features = [(self.extract_features(d), c) for d, c in self.train_set]
#     207
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/classifiers.py in __init__(self, train_set, feature_extractor, format, **kwargs)
#     137         else:  # train_set is a list of tuples
#     138             self.train_set = train_set
# --> 139         self._word_set = _get_words_from_dataset(self.train_set)  # Keep a hidden set of unique words.
#     140         self.train_features = None
#     141
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/classifiers.py in _get_words_from_dataset(dataset)
#      61             return words
#      62     all_words = chain.from_iterable(tokenize(words) for words, _ in dataset)
# ---> 63     return set(all_words)
#      64
#      65 def _get_document_tokens(document):
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/classifiers.py in <genexpr>(.0)
#      60         else:
#      61             return words
# ---> 62     all_words = chain.from_iterable(tokenize(words) for words, _ in dataset)
#      63     return set(all_words)
#      64
#
# ValueError: too many values to unpack (expected 2)

# %%
proba = cl.prob_classify("A church bell sounded mournfully far away")

print(round(proba.prob('And make me travel forth without my cloak'), 2))
# Out:
# 0

# %% [markdown]
# ### Concatenate all csv files

# %%
import csv
file_list = ['CSVs/processed/modern_love_proc.csv',
             'CSVs/processed/modern_mythology_folklore_proc.csv',
             'CSVs/processed/modern_nature_proc.csv', 
             'CSVs/processed/renaissance_love_proc.csv',
             'CSVs/processed/renaissance_mythology_folklore_proc.csv',
             'CSVs/processed/renaissance_nature_proc.csv']


for i in range(len(file_list)):
    with open(file_list[i], 'r') as the_file:
        csv_reader = csv.reader(the_file)
        next(csv_reader)
        with open('CSVs/processed/all_proc.csv', 'a+') as big_file:
            #fieldname = ['poem_line', 'poem_genre']
            csv_writer = csv.writer(big_file)
            
            for line in csv_reader:
                csv_writer.writerow(line)
                #print(line)

        the_file.close()

# %% [markdown]
# ### Tokenization of poems words into a nested list

# %%
import csv
from textblob import TextBlob
from tokenizers import WordTokenizer
#from tokenizers import WordTokenizer
my_string = "Alex's car is a top machine, I did't build myself"
matrix = []
mystr = WordTokenizer.tokenize(my_string)
matrix.append(mystr)

w = WordTokenizer()
with open ('CSVs/processed/test.csv', 'r') as csvfile:
    csv_reader = csv.DictReader(csvfile)
    data_lines = list(csv_reader)

    for line in data_lines:
        #poem_sentence = TextBlob(line['poem_line'])
        #textblob.tokenizers.WordTokenizer
        mystr = w.tokenize(my_string)
        matrix.append(mystr)
        
print(matrix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-047ece1b69f1> in <module>
#       5 my_string = "Alex's car is a top machine, I did't build myself"
#       6 matrix = []
# ----> 7 mystr = WordTokenizer.tokenize(my_string)
#       8 matrix.append(mystr)
#       9
#
# TypeError: tokenize() missing 1 required positional argument: 'text'

# %% [markdown]
# ### Read a csv file and print to the console and write to a new file for testing purposes

# %%
'''
m_love.csv
m_nature.csv
m_mythology.csv

r_love.csv
r_nature.csv
r_mythology.csv

modern_renaissance
'''

import csv

with open('CSVs/processed/all_proc.csv', 'r') as in_file:
    csv_reader = csv.reader(in_file)
    next(csv_reader)
    with open('CSVs/processed/modern_renaissance.csv', 'w') as out_file:
        csv_writer = csv.writer(out_file)
        for line in csv_reader:
            if(line[1] == 'modern_love' or line[1] == 'modern_nature' or line[1] == 'modern_mythology_folklore'):
                csv_writer.writerow([line[0]] + ['modern'])
                #print(line)
            else:
                csv_writer.writerow([line[0]] + ['renaissance'])
                
                
print('done')
            
            
            
            
#             #delete rows
#             if line:
#                 print(repr(line[0]))
#                 csv_writer.writerow(line)
                
#             # remove rows where all of the fields are empty
#             if any(line):
#                 csv_writer.writerow(line)
#                 print(line[0])
                
                
#             # treat fields that consist of only whitespace
#             if any(field.strip() for field in line):
#                 csv_writer.writerow(line)
#                 print(line)
# Out:
# done
